# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("atulyakumar98/gundetection")

print("Path to dataset files:", path)
# Out:
# Downloading to /home/murtaza-ali/.cache/kagglehub/datasets/atulyakumar98/gundetection/2.archive...
# 100%|██████████| 250M/250M [02:25<00:00, 1.80MB/s]
# Extracting files...
# Path to dataset files: /home/murtaza-ali/.cache/kagglehub/datasets/atulyakumar98/gundetection/versions/2
