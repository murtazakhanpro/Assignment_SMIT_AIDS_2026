# %%
import pandas as pd
from pycaret.regression import*

# %%
df_ml = pd.read_csv('process_data.csv')

# %%
df_ml.head()
# Out:
#   customer_id  age  gender    country  avg_order_value  total_orders  \
# 0   CUST_8270   30  Female     Brazil           101.08             8
# 1   CUST_1860   53  Female        USA            90.39            10
# 2   CUST_6390   73    Male  Australia            83.28             6
# 3   CUST_6191   30   Other      Japan           109.90             9
# 4   CUST_6734   29  Female     Canada           269.38            16
#
#    last_purchase  is_fraudulent preferred_category  email_open_rate  \
# 0            176              1             Beauty            25.60
# 1             88              0        Electronics            12.30
# 2            203              0             Sports            50.95
# 3            346              1        Electronics            42.90
# 4            342              0            Fashion             5.30
#
#    loyalty_score  churn_risk  customer_tenure_days  total_spend  \
# 0             50        0.20                   800       808.64
# ...

# %%
from pycaret.classification import *

# %%
cls = setup(
    data=df_ml,
    session_id=123,
    target='is_fraudulent',
    ignore_features=['customer_id','order_velociy' ]
)
# Out:
# <style type="text/css">
# #T_a5a8b_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_a5a8b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5a8b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_a5a8b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5a8b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a5a8b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_a5a8b_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_a5a8b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a5a8b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_a5a8b_row1_col1" class="data row1 col1" >is_fraudulent</td>
#     </tr>
#     <tr>
#       <th id="T_a5a8b_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
moddy = compare_models(include=['dt', 'rf', 'et', 'gbc'])
# Out:
# <style type="text/css">
# #T_8d57c th {
#   text-align: left;
# }
# #T_8d57c_row0_col0, #T_8d57c_row0_col2, #T_8d57c_row0_col3, #T_8d57c_row0_col4, #T_8d57c_row0_col5, #T_8d57c_row0_col6, #T_8d57c_row0_col7, #T_8d57c_row1_col0, #T_8d57c_row1_col3, #T_8d57c_row1_col4, #T_8d57c_row1_col5, #T_8d57c_row1_col6, #T_8d57c_row1_col7, #T_8d57c_row2_col0, #T_8d57c_row2_col1, #T_8d57c_row2_col2, #T_8d57c_row2_col3, #T_8d57c_row2_col4, #T_8d57c_row2_col5, #T_8d57c_row2_col6, #T_8d57c_row2_col7, #T_8d57c_row3_col0, #T_8d57c_row3_col1, #T_8d57c_row3_col2 {
#   text-align: left;
# }
# #T_8d57c_row0_col1, #T_8d57c_row1_col1, #T_8d57c_row1_col2, #T_8d57c_row3_col3, #T_8d57c_row3_col4, #T_8d57c_row3_col5, #T_8d57c_row3_col6, #T_8d57c_row3_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_8d57c_row0_col8, #T_8d57c_row2_col8, #T_8d57c_row3_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_8d57c_row1_col8 {
#   text-align: left;
#   background-color: yellow;
# ...

# %%
final_modle = tune_model(moddy)
# Out:
# <style type="text/css">
# #T_aab4c_row10_col0, #T_aab4c_row10_col1, #T_aab4c_row10_col2, #T_aab4c_row10_col3, #T_aab4c_row10_col4, #T_aab4c_row10_col5, #T_aab4c_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_aab4c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aab4c_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_aab4c_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_aab4c_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_aab4c_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_aab4c_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_aab4c_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_aab4c_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...
