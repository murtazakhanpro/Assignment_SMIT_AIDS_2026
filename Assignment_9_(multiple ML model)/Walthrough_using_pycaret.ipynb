# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('customer_analytics_dataset.csv')

# %%
df.sample(2)
# Out:
#      customer_id  age  gender    country  avg_order_value  total_orders  \
# 3745   CUST_2258   75  Female        USA            16.23             5
# 4426   CUST_3363   64    Male  Australia           151.08            13
#
#       last_purchase  is_fraudulent preferred_category  email_open_rate  \
# 3745             90              0             Beauty             23.9
# 4426            187              0               Home             17.4
#
#      customer_since  loyalty_score  churn_risk
# 3745     2021-08-29             41        0.22
# 4426     2021-09-05             38        0.17

# %%
df.shape
# Out:
# (5000, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         5000 non-null   object
#  1   age                 5000 non-null   int64
#  2   gender              5000 non-null   object
#  3   country             5000 non-null   object
#  4   avg_order_value     4750 non-null   float64
#  5   total_orders        5000 non-null   int64
#  6   last_purchase       5000 non-null   int64
#  7   is_fraudulent       5000 non-null   int64
#  8   preferred_category  5000 non-null   object
#  9   email_open_rate     4750 non-null   float64
#  10  customer_since      5000 non-null   object
#  11  loyalty_score       5000 non-null   int64
#  12  churn_risk          5000 non-null   float64
# dtypes: float64(3), int64(5), object(5)
# memory usage: 507.9+ KB

# %%
df.isnull().sum()
# Out:
# customer_id             0
# age                     0
# gender                  0
# country                 0
# avg_order_value       250
# total_orders            0
# last_purchase           0
# is_fraudulent           0
# preferred_category      0
# email_open_rate       250
# customer_since          0
# loyalty_score           0
# churn_risk              0
# dtype: int64

# %% [markdown]
# # setup

# %%
from pycaret.classification import setup, compare_models, predict_model, plot_model

# %%
clf_setup = setup(
    data=df, 
    target='is_fraudulent',         
    ignore_features=['customer_id', 'customer_since'],
    fix_imbalance=True,
    session_id=123
)

# isme sy bohat bar kuch parameter tune kr k dekhy hain usman bhai
# phir ja kr is upper wale result pr pohancy hain aur 
# best result aa raha hai
# clf_setup = setup(
#     data=df, 
#     target='is_fraudulent',         
#     ignore_features=['customer_id', 'customer_since'],
#     # normalize=True,
#     # normalize_method='zscore',
#     fix_imbalance=True,
#     session_id=123
# )
# Out:
# <style type="text/css">
# #T_590b2_row11_col1, #T_590b2_row17_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_590b2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_590b2_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_590b2_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_590b2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_590b2_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_590b2_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_590b2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_590b2_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_590b2_row1_col1" class="data row1 col1" >is_fraudulent</td>
#     </tr>
#     <tr>
#       <th id="T_590b2_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# required_models = ['rf', 'dt', 'et', 'gbc' , 'ada']

# %% [markdown]
# ##### mane phely saray classification models ko apply kr k dekha tha but yeh 5 final hue hain mere jo best of best of best results provide kr rahe hain

# %%
best_model = compare_models(
    include=['rf', 'dt', 'et', 'gbc', 'ada'],
    sort='F1'
)
# f1 ki base pr sort kia hai mane
# Out:
# <style type="text/css">
# #T_12aee th {
#   text-align: left;
# }
# #T_12aee_row0_col0, #T_12aee_row0_col1, #T_12aee_row0_col2, #T_12aee_row0_col6, #T_12aee_row0_col7, #T_12aee_row1_col0, #T_12aee_row1_col1, #T_12aee_row1_col2, #T_12aee_row1_col3, #T_12aee_row1_col4, #T_12aee_row1_col5, #T_12aee_row1_col6, #T_12aee_row1_col7, #T_12aee_row2_col0, #T_12aee_row2_col1, #T_12aee_row2_col2, #T_12aee_row2_col3, #T_12aee_row2_col4, #T_12aee_row2_col5, #T_12aee_row2_col6, #T_12aee_row2_col7, #T_12aee_row3_col0, #T_12aee_row3_col1, #T_12aee_row3_col3, #T_12aee_row3_col4, #T_12aee_row3_col5, #T_12aee_row3_col6, #T_12aee_row3_col7, #T_12aee_row4_col0, #T_12aee_row4_col2, #T_12aee_row4_col3, #T_12aee_row4_col4, #T_12aee_row4_col5 {
#   text-align: left;
# }
# #T_12aee_row0_col3, #T_12aee_row0_col4, #T_12aee_row0_col5, #T_12aee_row3_col2, #T_12aee_row4_col1, #T_12aee_row4_col6, #T_12aee_row4_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_12aee_row0_col8 {
# ...

# %%
# tune_model = tune_model(best_model)

# %%
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
plot_model(best_model, plot='class_report')

# %%
import pandas as pd

df_ready = pd.read_csv('readyforML.csv')

# %%
df_ready.head()
# Out:
#         age  avg_order_value  total_orders  last_purchase  email_open_rate  \
# 0  0.885776         0.076491     -0.324638      -1.020561        -0.007990
# 1 -0.736238         2.140960      0.939775       0.418685         1.272028
# 2 -0.456580        -0.255972     -0.956845       0.714160         0.446892
# 3  1.389160        -0.187911     -0.324638      -0.286641        -0.660341
# 4 -0.288786        -1.186336     -0.008535      -0.286641         0.912353
#
#    loyalty_score  churn_risk  customer_tenure_days
# 0       0.033320    0.535566              0.470745
# 1       1.698295   -0.842241              1.648471
# 2       1.455486   -1.155378              1.689993
# 3      -0.036054   -0.529103              1.633372
# 4      -1.284785   -0.904868             -0.533341

# %%
from pycaret.classification import setup, compare_models, predict_model, plot_model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from pycaret.classification import setup, compare_models, predict_model, plot_model
#
# ModuleNotFoundError: No module named 'pycaret'
